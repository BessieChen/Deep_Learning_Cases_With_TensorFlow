# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from PIL import Image

DIR = './001_style_transfer_output'
DIR2 = './002_content_rebuild_output_shallow'
DIR3 = './003_content_rebuild_output_deep'
DIR4 = './004_style_rebuild_output_deep'
DIR5 = './005_style_rebuild_output_shallow'

image_name = 'result-00100.jpg'

# %% [markdown]
# ### 风格转换

# %%
img = Image.open(os.path.join(DIR, image_name))
print(img.size)

img_arr = np.asarray(img)
# %matplotlib inline
imshow(img_arr)
# Out:
# (224, 224)

# %% [markdown]
# ### 浅层 + 内容重现

# %%
img = Image.open(os.path.join(DIR2, image_name))
print(img.size)

img_arr = np.asarray(img)
# %matplotlib inline
imshow(img_arr)
# Out:
# (224, 224)

# %% [markdown]
# ### 深层 + 内容重现

# %%
img = Image.open(os.path.join(DIR3, image_name))
print(img.size)

img_arr = np.asarray(img)
# %matplotlib inline
imshow(img_arr)
# Out:
# (224, 224)

# %% [markdown]
# ### 深层 + 风格重现

# %%
img = Image.open(os.path.join(DIR4, image_name))
print(img.size)

img_arr = np.asarray(img)
# %matplotlib inline
imshow(img_arr)
# Out:
# (224, 224)

# %% [markdown]
# ### 浅层 + 风格重现

# %%
img = Image.open(os.path.join(DIR5, image_name))
print(img.size)

img_arr = np.asarray(img)
# %matplotlib inline
imshow(img_arr)
# Out:
# (224, 224)
